# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      1.4.0
# aiohappyeyeballs             2.4.6
# aiohttp                      3.11.12
# aiosignal                    1.3.2
# anyio                        4.6.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# array_record                 0.5.1
# asttokens                    2.0.5
# astunparse                   1.6.3
# async-lru                    2.0.4
# async-timeout                5.0.1
# attrs                        24.3.0
# babel                        2.16.0
# backcall                     0.2.0
# beautifulsoup4               4.12.3
# bleach                       6.2.0
# blinker                      1.9.0
# Bottleneck                   1.4.2
# Brotli                       1.0.9
# cached-property              1.5.2
# cachetools                   5.5.1
# certifi                      2025.1.31
# cffi                         1.17.1
# ...
